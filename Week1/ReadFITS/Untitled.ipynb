# %%
from astropy.io import fits
import matplotlib.pyplot as plt
import numpy as np

# %%
def load_fits(file):
    hdul = fits.open(file)
    
    data = hdul[0].data
    arg_max = np.argmax(data)
    pos = np.unravel_index(arg_max, data.shape)
    
    return pos

# %%
if __name__ == '__main__':
    # Run your `load_fits` function with examples:
    img = 'image0.fits'
    bright = load_fits(img)
    print(bright)

    # You can also confirm your result visually:

    hdulist = fits.open(img)
    data = hdulist[0].data

    # Plot the 2D image data
    plt.imshow(data.T, cmap=plt.cm.viridis)
    plt.colorbar()
    plt.show()
# Out:
# (100, 100)

# %%
if __name__ == '__main__':
    # Run your `load_fits` function with examples:
    img = 'image1.fits'
    bright = load_fits(img)
    print(bright)

    # You can also confirm your result visually:

    hdulist = fits.open(img)
    data = hdulist[0].data

    # Plot the 2D image data
    plt.imshow(data.T, cmap=plt.cm.viridis)
    plt.colorbar()
    plt.show()
# Out:
# (101, 100)

# %%
if __name__ == '__main__':
    # Run your `load_fits` function with examples:
    img = 'image2.fits'
    bright = load_fits(img)
    print(bright)

    # You can also confirm your result visually:

    hdulist = fits.open(img)
    data = hdulist[0].data

    # Plot the 2D image data
    plt.imshow(data.T, cmap=plt.cm.viridis)
    plt.colorbar()
    plt.show()
# Out:
# (14, 125)

# %%
if __name__ == '__main__':
    # Run your `load_fits` function with examples:
    img = 'image3.fits'
    bright = load_fits(img)
    print(bright)

    # You can also confirm your result visually:

    hdulist = fits.open(img)
    data = hdulist[0].data

    # Plot the 2D image data
    plt.imshow(data.T, cmap=plt.cm.viridis)
    plt.colorbar()
    plt.show()
# Out:
# (4, 55)
